# %% [markdown]
# # Training
# =>reference to TORCHVISION OBJECT DETECTION FINETUNING TUTORIAL.

# %%
import os
import numpy as np
import torch
import torchvision
from PIL import Image
import transforms as T
from engine import train_one_epoch, evaluate
# import natsort
import utils

# %%
torch.cuda.is_available()
# Out:
# True

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3"

# %%
#import data using extension
EXTENSIONS_LABEL = ['.npy']
EXTENSIONS_IMAGE = ['.png']

def is_label(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS_LABEL)

def is_image(filename):
    return any(filename.endswith(ext) for ext in EXTENSIONS_IMAGE)

# %%
class TrainDataset(object):
    def __init__(self,imgpath,labelpath,transforms):
        
        self.transforms = transforms
        # placeholder for filenames
        self.imgs = []
        self.masks = []

        # get paths for each
        image_path = imgpath
        label_path = labelpath

        # get files
        image_files = [os.path.join(dp, f) for dp, dn, fn in os.walk(
            os.path.expanduser(image_path)) for f in fn if is_image(f)]

        label_files = [os.path.join(dp, f) for dp, dn, fn in os.walk(
            os.path.expanduser(label_path)) for f in fn if is_label(f)]


        # sort 1,10,11,...
        # natsort 1,2,3,...
        label_files.sort()
        image_files.sort()

        self.imgs.extend(image_files)
        self.masks.extend(label_files)

    def __getitem__(self, idx):
        # read image & label
        img_path = self.imgs[idx]
        mask_path = self.masks[idx]
        img = Image.open(img_path).convert("RGB")
        mask = np.load(mask_path, allow_pickle=True)

        # 1st dim is background.
        obj_ids = np.unique(mask)        
        obj_ids = obj_ids[1:]
        
        # split the color-encoded mask into a set
        # of binary masks
        masks = mask == obj_ids[:, None, None]

        # get bounding box coordinates for each mask
        num_objs = len(obj_ids)
        boxes = []
        for i in range(num_objs):
            pos = np.where(masks[i])
            xmin = np.min(pos[1])
            xmax = np.max(pos[1])
            ymin = np.min(pos[0])
            ymax = np.max(pos[0])

            boxes.append([xmin, ymin, xmax, ymax])
            
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        # there is only one class for easy to follow
        labels = torch.ones((num_objs,), dtype=torch.int64)
        masks = torch.as_tensor(masks, dtype=torch.uint8)
        name = self.imgs[idx].split('/')[-1].split('.')[0]
        image_id = torch.tensor([idx])
        image_name = name
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
def get_transform(train):
    transforms = []
    transforms.append(T.ToTensor())
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# %%
def get_model_instance_segmentation(num_classes):
    # load a model pre-trained on COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # get number of input features for the classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    # replace the pre-trained head with a weighted mask r-cnn head
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                       hidden_layer,
                                                       num_classes)

    return model

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
model = get_model_instance_segmentation(2)
#cpu or gpu
model = model.to(device)

# %%
imgpath = "/mnt/nas3/ssm/algae_dataset/algae_total/train/resized_image"
labpath = "/mnt/nas3/ssm/algae_dataset/algae_total/train/npy"

dataset = TrainDataset(imgpath,labpath,get_transform(train=True))
dataset_test = TrainDataset(imgpath,labpath,get_transform(train=False))

indices = torch.randperm(len(dataset)).tolist()

dataset = torch.utils.data.Subset(dataset, indices[:-150])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-150:])

data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=1, shuffle=True, num_workers=8,
    collate_fn=utils.collate_fn)
data_loader_test = torch.utils.data.DataLoader(
        dataset_test, batch_size=1, shuffle=False, num_workers=8,
        collate_fn=utils.collate_fn)

# %%
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %%
num_epochs = 5

for epoch in range(num_epochs):
    # 1 에포크동안 학습하고, 10회 마다 출력합니다
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # 학습률을 업데이트 합니다
    lr_scheduler.step()
    # 테스트 데이터셋에서 평가를 합니다
    # evaluate(model, data_loader, device=device)
    evaluate(model, data_loader_test, device=device)
# Out:
# /opt/anaconda3/envs/mrcnn/lib/python3.8/site-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# Epoch: [0]  [  0/319]  eta: 0:03:43  lr: 0.000021  loss: 3.1239 (3.1239)  loss_classifier: 0.6607 (0.6607)  loss_box_reg: 0.0841 (0.0841)  loss_mask: 2.3467 (2.3467)  loss_objectness: 0.0288 (0.0288)  loss_rpn_box_reg: 0.0035 (0.0035)  time: 0.6994  data: 0.4588  max mem: 966
# Epoch: [0]  [ 10/319]  eta: 0:01:33  lr: 0.000178  loss: 2.1744 (2.9177)  loss_classifier: 0.5131 (0.5248)  loss_box_reg: 0.2317 (0.2662)  loss_mask: 1.2537 (1.9761)  loss_objectness: 0.0527 (0.1372)  loss_rpn_box_reg: 0.0056 (0.0134)  time: 0.3038  data: 0.0725  max mem: 1303
# Epoch: [0]  [ 20/319]  eta: 0:01:20  lr: 0.000335  loss: 1.8445 (2.1124)  loss_classifier: 0.3454 (0.3863)  loss_box_reg: 0.2046 (0.2804)  loss_mask: 1.0416 (1.3383)  loss_objectness: 0.0249 (0.0961)  loss_rpn_box_reg: 0.0054 (0.0113)  time: 0.2467  data: 0.0180  max mem: 1504
# Epoch: [0]  [ 30/319]  eta: 0:01:12  lr: 0.000492  loss: 0.8008 (1.7099)  loss_classifier: 0.1852 (0.3246)  loss_box_reg: 0.1945 (0.2786)  loss_mask: 0.3396 (1.0257)  loss_objectness: 0.0149 (0.0717)  loss_rpn_box_reg: 0.0044 (0.0093)  time: 0.2238  data: 0.0026  max mem: 1504
# Epoch: [0]  [ 40/319]  eta: 0:01:06  lr: 0.000649  loss: 0.6175 (1.4663)  loss_classifier: 0.1056 (0.2817)  loss_box_reg: 0.1718 (0.2692)  loss_mask: 0.3162 (0.8473)  loss_objectness: 0.0149 (0.0600)  loss_rpn_box_reg: 0.0019 (0.0080)  time: 0.2104  data: 0.0033  max mem: 1504
# Epoch: [0]  [ 50/319]  eta: 0:01:03  lr: 0.000806  loss: 0.5756 (1.3244)  loss_classifier: 0.0886 (0.2554)  loss_box_reg: 0.1718 (0.2799)  loss_mask: 0.2271 (0.7310)  loss_objectness: 0.0101 (0.0506)  loss_rpn_box_reg: 0.0023 (0.0076)  time: 0.2093  data: 0.0034  max mem: 1504
# Epoch: [0]  [ 60/319]  eta: 0:01:00  lr: 0.000963  loss: 0.5128 (1.2101)  loss_classifier: 0.0979 (0.2336)  loss_box_reg: 0.1990 (0.2784)  loss_mask: 0.2060 (0.6470)  loss_objectness: 0.0049 (0.0438)  loss_rpn_box_reg: 0.0030 (0.0073)  time: 0.2146  data: 0.0033  max mem: 1504
# Epoch: [0]  [ 70/319]  eta: 0:00:58  lr: 0.001120  loss: 0.4538 (1.1399)  loss_classifier: 0.0975 (0.2234)  loss_box_reg: 0.1895 (0.2851)  loss_mask: 0.1876 (0.5828)  loss_objectness: 0.0040 (0.0414)  loss_rpn_box_reg: 0.0013 (0.0073)  time: 0.2310  data: 0.0035  max mem: 1504
# Epoch: [0]  [ 80/319]  eta: 0:00:55  lr: 0.001277  loss: 0.4230 (1.0553)  loss_classifier: 0.0799 (0.2077)  loss_box_reg: 0.1375 (0.2729)  loss_mask: 0.1773 (0.5311)  loss_objectness: 0.0024 (0.0370)  loss_rpn_box_reg: 0.0008 (0.0067)  time: 0.2258  data: 0.0034  max mem: 1504
# Epoch: [0]  [ 90/319]  eta: 0:00:52  lr: 0.001434  loss: 0.4230 (0.9975)  loss_classifier: 0.0622 (0.1944)  loss_box_reg: 0.1375 (0.2630)  loss_mask: 0.1738 (0.5001)  loss_objectness: 0.0024 (0.0336)  loss_rpn_box_reg: 0.0016 (0.0065)  time: 0.2055  data: 0.0034  max mem: 1504
# Epoch: [0]  [100/319]  eta: 0:00:49  lr: 0.001591  loss: 0.3830 (0.9411)  loss_classifier: 0.0622 (0.1817)  loss_box_reg: 0.1026 (0.2504)  loss_mask: 0.1715 (0.4723)  loss_objectness: 0.0021 (0.0305)  loss_rpn_box_reg: 0.0030 (0.0061)  time: 0.2092  data: 0.0035  max mem: 1504
# Epoch: [0]  [110/319]  eta: 0:00:47  lr: 0.001749  loss: 0.3245 (0.9074)  loss_classifier: 0.0528 (0.1787)  loss_box_reg: 0.0881 (0.2427)  loss_mask: 0.1666 (0.4478)  loss_objectness: 0.0008 (0.0322)  loss_rpn_box_reg: 0.0016 (0.0061)  time: 0.2281  data: 0.0036  max mem: 1507
# Epoch: [0]  [120/319]  eta: 0:00:45  lr: 0.001906  loss: 0.3245 (0.8761)  loss_classifier: 0.0562 (0.1755)  loss_box_reg: 0.0906 (0.2352)  loss_mask: 0.1508 (0.4273)  loss_objectness: 0.0018 (0.0319)  loss_rpn_box_reg: 0.0016 (0.0062)  time: 0.2308  data: 0.0036  max mem: 1507
# Epoch: [0]  [130/319]  eta: 0:00:42  lr: 0.002063  loss: 0.3195 (0.8437)  loss_classifier: 0.0688 (0.1688)  loss_box_reg: 0.0995 (0.2295)  loss_mask: 0.1325 (0.4093)  loss_objectness: 0.0031 (0.0299)  loss_rpn_box_reg: 0.0020 (0.0062)  time: 0.2142  data: 0.0035  max mem: 1507
# Epoch: [0]  [140/319]  eta: 0:00:40  lr: 0.002220  loss: 0.4064 (0.8217)  loss_classifier: 0.0635 (0.1652)  loss_box_reg: 0.1055 (0.2246)  loss_mask: 0.1684 (0.3969)  loss_objectness: 0.0031 (0.0289)  loss_rpn_box_reg: 0.0026 (0.0061)  time: 0.2180  data: 0.0035  max mem: 1507
# Epoch: [0]  [150/319]  eta: 0:00:38  lr: 0.002377  loss: 0.4256 (0.8050)  loss_classifier: 0.0704 (0.1616)  loss_box_reg: 0.1208 (0.2205)  loss_mask: 0.2383 (0.3893)  loss_objectness: 0.0077 (0.0275)  loss_rpn_box_reg: 0.0041 (0.0061)  time: 0.2233  data: 0.0033  max mem: 1507
# Epoch: [0]  [160/319]  eta: 0:00:35  lr: 0.002534  loss: 0.4192 (0.7814)  loss_classifier: 0.0684 (0.1565)  loss_box_reg: 0.0861 (0.2144)  loss_mask: 0.2251 (0.3782)  loss_objectness: 0.0061 (0.0263)  loss_rpn_box_reg: 0.0032 (0.0059)  time: 0.2189  data: 0.0034  max mem: 1507
# Epoch: [0]  [170/319]  eta: 0:00:33  lr: 0.002691  loss: 0.3713 (0.7654)  loss_classifier: 0.0532 (0.1518)  loss_box_reg: 0.0916 (0.2088)  loss_mask: 0.2137 (0.3738)  loss_objectness: 0.0037 (0.0253)  loss_rpn_box_reg: 0.0020 (0.0058)  time: 0.2089  data: 0.0033  max mem: 1507
# Epoch: [0]  [180/319]  eta: 0:00:30  lr: 0.002848  loss: 0.3753 (0.7511)  loss_classifier: 0.0495 (0.1484)  loss_box_reg: 0.0836 (0.2046)  loss_mask: 0.2405 (0.3682)  loss_objectness: 0.0011 (0.0243)  loss_rpn_box_reg: 0.0019 (0.0057)  time: 0.2042  data: 0.0031  max mem: 1507
# Epoch: [0]  [190/319]  eta: 0:00:28  lr: 0.003005  loss: 0.3195 (0.7322)  loss_classifier: 0.0495 (0.1454)  loss_box_reg: 0.0840 (0.2003)  loss_mask: 0.1825 (0.3574)  loss_objectness: 0.0010 (0.0234)  loss_rpn_box_reg: 0.0018 (0.0056)  time: 0.2045  data: 0.0035  max mem: 1507
# Epoch: [0]  [200/319]  eta: 0:00:26  lr: 0.003162  loss: 0.3564 (0.7363)  loss_classifier: 0.0767 (0.1490)  loss_box_reg: 0.1025 (0.2003)  loss_mask: 0.1711 (0.3569)  loss_objectness: 0.0053 (0.0243)  loss_rpn_box_reg: 0.0048 (0.0059)  time: 0.2192  data: 0.0039  max mem: 1507
# Epoch: [0]  [210/319]  eta: 0:00:24  lr: 0.003319  loss: 0.5583 (0.7281)  loss_classifier: 0.1252 (0.1492)  loss_box_reg: 0.1316 (0.1981)  loss_mask: 0.2263 (0.3507)  loss_objectness: 0.0110 (0.0242)  loss_rpn_box_reg: 0.0036 (0.0058)  time: 0.2293  data: 0.0038  max mem: 1507
# Epoch: [0]  [220/319]  eta: 0:00:21  lr: 0.003476  loss: 0.3599 (0.7084)  loss_classifier: 0.0996 (0.1455)  loss_box_reg: 0.0776 (0.1928)  loss_mask: 0.1686 (0.3410)  loss_objectness: 0.0041 (0.0233)  loss_rpn_box_reg: 0.0019 (0.0057)  time: 0.2140  data: 0.0033  max mem: 1507
# Epoch: [0]  [230/319]  eta: 0:00:19  lr: 0.003633  loss: 0.3214 (0.6970)  loss_classifier: 0.0460 (0.1424)  loss_box_reg: 0.0772 (0.1893)  loss_mask: 0.1500 (0.3372)  loss_objectness: 0.0019 (0.0225)  loss_rpn_box_reg: 0.0026 (0.0056)  time: 0.2014  data: 0.0031  max mem: 1507
# Epoch: [0]  [240/319]  eta: 0:00:17  lr: 0.003791  loss: 0.3442 (0.6846)  loss_classifier: 0.0506 (0.1392)  loss_box_reg: 0.0863 (0.1861)  loss_mask: 0.2361 (0.3318)  loss_objectness: 0.0023 (0.0220)  loss_rpn_box_reg: 0.0031 (0.0055)  time: 0.2022  data: 0.0033  max mem: 1507
# Epoch: [0]  [250/319]  eta: 0:00:15  lr: 0.003948  loss: 0.3069 (0.6674)  loss_classifier: 0.0327 (0.1352)  loss_box_reg: 0.0622 (0.1810)  loss_mask: 0.1342 (0.3244)  loss_objectness: 0.0039 (0.0214)  loss_rpn_box_reg: 0.0021 (0.0054)  time: 0.1947  data: 0.0033  max mem: 1507
# Epoch: [0]  [260/319]  eta: 0:00:12  lr: 0.004105  loss: 0.2395 (0.6578)  loss_classifier: 0.0380 (0.1340)  loss_box_reg: 0.0535 (0.1790)  loss_mask: 0.1229 (0.3186)  loss_objectness: 0.0037 (0.0208)  loss_rpn_box_reg: 0.0017 (0.0054)  time: 0.1955  data: 0.0033  max mem: 1507
# Epoch: [0]  [270/319]  eta: 0:00:10  lr: 0.004262  loss: 0.2201 (0.6525)  loss_classifier: 0.0443 (0.1335)  loss_box_reg: 0.0558 (0.1786)  loss_mask: 0.1260 (0.3145)  loss_objectness: 0.0009 (0.0204)  loss_rpn_box_reg: 0.0017 (0.0054)  time: 0.2148  data: 0.0035  max mem: 1507
# Epoch: [0]  [280/319]  eta: 0:00:08  lr: 0.004419  loss: 0.5140 (0.6484)  loss_classifier: 0.0942 (0.1334)  loss_box_reg: 0.1441 (0.1790)  loss_mask: 0.1440 (0.3107)  loss_objectness: 0.0028 (0.0200)  loss_rpn_box_reg: 0.0029 (0.0054)  time: 0.2264  data: 0.0034  max mem: 1507
# Epoch: [0]  [290/319]  eta: 0:00:06  lr: 0.004576  loss: 0.3072 (0.6377)  loss_classifier: 0.0775 (0.1315)  loss_box_reg: 0.0888 (0.1760)  loss_mask: 0.1440 (0.3054)  loss_objectness: 0.0051 (0.0195)  loss_rpn_box_reg: 0.0021 (0.0053)  time: 0.2230  data: 0.0034  max mem: 1507
# Epoch: [0]  [300/319]  eta: 0:00:04  lr: 0.004733  loss: 0.2695 (0.6408)  loss_classifier: 0.0524 (0.1311)  loss_box_reg: 0.0696 (0.1740)  loss_mask: 0.1426 (0.3015)  loss_objectness: 0.0057 (0.0283)  loss_rpn_box_reg: 0.0007 (0.0059)  time: 0.2164  data: 0.0035  max mem: 1507
# Epoch: [0]  [310/319]  eta: 0:00:01  lr: 0.004890  loss: 0.3660 (0.6366)  loss_classifier: 0.0566 (0.1300)  loss_box_reg: 0.0785 (0.1717)  loss_mask: 0.1498 (0.2975)  loss_objectness: 0.0307 (0.0315)  loss_rpn_box_reg: 0.0021 (0.0059)  time: 0.2152  data: 0.0036  max mem: 1507
# Epoch: [0]  [318/319]  eta: 0:00:00  lr: 0.005000  loss: 0.3654 (0.6266)  loss_classifier: 0.0463 (0.1276)  loss_box_reg: 0.0517 (0.1686)  loss_mask: 0.1382 (0.2936)  loss_objectness: 0.0290 (0.0310)  loss_rpn_box_reg: 0.0020 (0.0058)  time: 0.1971  data: 0.0034  max mem: 1507
# Epoch: [0] Total time: 0:01:09 (0.2176 s / it)
# creating index...
# index created!
# Test:  [  0/150]  eta: 0:01:21  model_time: 0.0814 (0.0814)  evaluator_time: 0.0188 (0.0188)  time: 0.5415  data: 0.4200  max mem: 1507
# Test:  [100/150]  eta: 0:00:04  model_time: 0.0609 (0.0661)  evaluator_time: 0.0132 (0.0161)  time: 0.0840  data: 0.0041  max mem: 1507
# Test:  [149/150]  eta: 0:00:00  model_time: 0.0610 (0.0667)  evaluator_time: 0.0133 (0.0171)  time: 0.0850  data: 0.0040  max mem: 1507
# Test: Total time: 0:00:14 (0.0940 s / it)
# Averaged stats: model_time: 0.0610 (0.0667)  evaluator_time: 0.0133 (0.0171)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.444
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.639
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.507
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.509
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.579
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.586
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.186
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.655
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.424
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.632
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.460
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.486
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.545
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.618
# Epoch: [1]  [  0/319]  eta: 0:02:54  lr: 0.005000  loss: 0.6725 (0.6725)  loss_classifier: 0.0247 (0.0247)  loss_box_reg: 0.0247 (0.0247)  loss_mask: 0.6196 (0.6196)  loss_objectness: 0.0023 (0.0023)  loss_rpn_box_reg: 0.0012 (0.0012)  time: 0.5457  data: 0.3460  max mem: 1507
# Epoch: [1]  [ 10/319]  eta: 0:01:14  lr: 0.005000  loss: 0.3115 (0.4293)  loss_classifier: 0.0422 (0.0774)  loss_box_reg: 0.0581 (0.0887)  loss_mask: 0.1972 (0.2392)  loss_objectness: 0.0086 (0.0172)  loss_rpn_box_reg: 0.0015 (0.0069)  time: 0.2425  data: 0.0354  max mem: 1507
# Epoch: [1]  [ 20/319]  eta: 0:01:08  lr: 0.005000  loss: 0.3235 (0.4452)  loss_classifier: 0.0455 (0.0812)  loss_box_reg: 0.0709 (0.1242)  loss_mask: 0.1972 (0.2193)  loss_objectness: 0.0102 (0.0149)  loss_rpn_box_reg: 0.0019 (0.0057)  time: 0.2149  data: 0.0032  max mem: 1507
# Epoch: [1]  [ 30/319]  eta: 0:01:03  lr: 0.005000  loss: 0.3736 (0.4197)  loss_classifier: 0.0673 (0.0836)  loss_box_reg: 0.0706 (0.1157)  loss_mask: 0.1776 (0.2014)  loss_objectness: 0.0095 (0.0138)  loss_rpn_box_reg: 0.0026 (0.0053)  time: 0.2074  data: 0.0029  max mem: 1507
# Epoch: [1]  [ 40/319]  eta: 0:01:01  lr: 0.005000  loss: 0.3370 (0.4320)  loss_classifier: 0.0663 (0.0850)  loss_box_reg: 0.0935 (0.1177)  loss_mask: 0.1777 (0.2129)  loss_objectness: 0.0033 (0.0115)  loss_rpn_box_reg: 0.0028 (0.0049)  time: 0.2080  data: 0.0034  max mem: 1507
# Epoch: [1]  [ 50/319]  eta: 0:00:58  lr: 0.005000  loss: 0.4099 (0.4470)  loss_classifier: 0.0542 (0.0843)  loss_box_reg: 0.1052 (0.1213)  loss_mask: 0.2128 (0.2256)  loss_objectness: 0.0033 (0.0112)  loss_rpn_box_reg: 0.0030 (0.0047)  time: 0.2152  data: 0.0033  max mem: 1507
# Epoch: [1]  [ 60/319]  eta: 0:00:55  lr: 0.005000  loss: 0.3077 (0.4247)  loss_classifier: 0.0449 (0.0792)  loss_box_reg: 0.0790 (0.1155)  loss_mask: 0.1911 (0.2154)  loss_objectness: 0.0043 (0.0103)  loss_rpn_box_reg: 0.0016 (0.0043)  time: 0.2051  data: 0.0033  max mem: 1507
# Epoch: [1]  [ 70/319]  eta: 0:00:52  lr: 0.005000  loss: 0.2728 (0.4134)  loss_classifier: 0.0488 (0.0764)  loss_box_reg: 0.0467 (0.1099)  loss_mask: 0.1672 (0.2133)  loss_objectness: 0.0044 (0.0098)  loss_rpn_box_reg: 0.0013 (0.0039)  time: 0.1967  data: 0.0033  max mem: 1507
# Epoch: [1]  [ 80/319]  eta: 0:00:50  lr: 0.005000  loss: 0.2291 (0.3995)  loss_classifier: 0.0386 (0.0747)  loss_box_reg: 0.0450 (0.1053)  loss_mask: 0.1448 (0.2062)  loss_objectness: 0.0047 (0.0095)  loss_rpn_box_reg: 0.0012 (0.0038)  time: 0.1971  data: 0.0034  max mem: 1507
# Epoch: [1]  [ 90/319]  eta: 0:00:48  lr: 0.005000  loss: 0.2154 (0.3835)  loss_classifier: 0.0348 (0.0714)  loss_box_reg: 0.0414 (0.1016)  loss_mask: 0.1232 (0.1980)  loss_objectness: 0.0040 (0.0090)  loss_rpn_box_reg: 0.0017 (0.0037)  time: 0.2033  data: 0.0035  max mem: 1507
# Epoch: [1]  [100/319]  eta: 0:00:47  lr: 0.005000  loss: 0.2561 (0.4027)  loss_classifier: 0.0419 (0.0774)  loss_box_reg: 0.0640 (0.1067)  loss_mask: 0.1310 (0.2005)  loss_objectness: 0.0049 (0.0126)  loss_rpn_box_reg: 0.0030 (0.0055)  time: 0.2315  data: 0.0038  max mem: 1507
# Epoch: [1]  [110/319]  eta: 0:00:44  lr: 0.005000  loss: 0.2778 (0.3994)  loss_classifier: 0.0522 (0.0778)  loss_box_reg: 0.0640 (0.1065)  loss_mask: 0.1429 (0.1967)  loss_objectness: 0.0079 (0.0129)  loss_rpn_box_reg: 0.0030 (0.0055)  time: 0.2377  data: 0.0037  max mem: 1507
# Epoch: [1]  [120/319]  eta: 0:00:42  lr: 0.005000  loss: 0.2465 (0.4050)  loss_classifier: 0.0376 (0.0780)  loss_box_reg: 0.0483 (0.1054)  loss_mask: 0.1458 (0.2031)  loss_objectness: 0.0074 (0.0131)  loss_rpn_box_reg: 0.0020 (0.0054)  time: 0.2221  data: 0.0034  max mem: 1507
# Epoch: [1]  [130/319]  eta: 0:00:40  lr: 0.005000  loss: 0.2499 (0.3983)  loss_classifier: 0.0351 (0.0770)  loss_box_reg: 0.0446 (0.1028)  loss_mask: 0.1517 (0.2004)  loss_objectness: 0.0052 (0.0127)  loss_rpn_box_reg: 0.0020 (0.0053)  time: 0.2101  data: 0.0034  max mem: 1507
# Epoch: [1]  [140/319]  eta: 0:00:38  lr: 0.005000  loss: 0.2860 (0.4096)  loss_classifier: 0.0691 (0.0801)  loss_box_reg: 0.0456 (0.1056)  loss_mask: 0.1676 (0.2042)  loss_objectness: 0.0039 (0.0142)  loss_rpn_box_reg: 0.0024 (0.0056)  time: 0.2119  data: 0.0034  max mem: 1507
# Epoch: [1]  [150/319]  eta: 0:00:36  lr: 0.005000  loss: 0.3522 (0.4115)  loss_classifier: 0.0779 (0.0812)  loss_box_reg: 0.0732 (0.1061)  loss_mask: 0.1778 (0.2042)  loss_objectness: 0.0116 (0.0145)  loss_rpn_box_reg: 0.0022 (0.0055)  time: 0.2238  data: 0.0034  max mem: 1507
# Epoch: [1]  [160/319]  eta: 0:00:34  lr: 0.005000  loss: 0.3258 (0.4085)  loss_classifier: 0.0491 (0.0817)  loss_box_reg: 0.0675 (0.1052)  loss_mask: 0.1605 (0.2018)  loss_objectness: 0.0128 (0.0145)  loss_rpn_box_reg: 0.0018 (0.0054)  time: 0.2153  data: 0.0034  max mem: 1507
# Epoch: [1]  [170/319]  eta: 0:00:32  lr: 0.005000  loss: 0.2522 (0.4030)  loss_classifier: 0.0491 (0.0810)  loss_box_reg: 0.0541 (0.1038)  loss_mask: 0.1541 (0.1987)  loss_objectness: 0.0077 (0.0142)  loss_rpn_box_reg: 0.0020 (0.0053)  time: 0.2107  data: 0.0035  max mem: 1507
# Epoch: [1]  [180/319]  eta: 0:00:29  lr: 0.005000  loss: 0.2844 (0.4017)  loss_classifier: 0.0587 (0.0807)  loss_box_reg: 0.0556 (0.1037)  loss_mask: 0.1576 (0.1977)  loss_objectness: 0.0066 (0.0142)  loss_rpn_box_reg: 0.0020 (0.0053)  time: 0.2054  data: 0.0034  max mem: 1507
# Epoch: [1]  [190/319]  eta: 0:00:27  lr: 0.005000  loss: 0.2844 (0.3967)  loss_classifier: 0.0587 (0.0797)  loss_box_reg: 0.0669 (0.1028)  loss_mask: 0.1479 (0.1952)  loss_objectness: 0.0042 (0.0138)  loss_rpn_box_reg: 0.0020 (0.0052)  time: 0.2049  data: 0.0034  max mem: 1507
# Epoch: [1]  [200/319]  eta: 0:00:25  lr: 0.005000  loss: 0.2495 (0.3924)  loss_classifier: 0.0432 (0.0784)  loss_box_reg: 0.0487 (0.1014)  loss_mask: 0.1479 (0.1939)  loss_objectness: 0.0043 (0.0136)  loss_rpn_box_reg: 0.0022 (0.0052)  time: 0.2083  data: 0.0035  max mem: 1507
# Epoch: [1]  [210/319]  eta: 0:00:23  lr: 0.005000  loss: 0.2530 (0.3940)  loss_classifier: 0.0420 (0.0805)  loss_box_reg: 0.0572 (0.1024)  loss_mask: 0.1503 (0.1926)  loss_objectness: 0.0049 (0.0133)  loss_rpn_box_reg: 0.0025 (0.0052)  time: 0.2141  data: 0.0035  max mem: 1507
# Epoch: [1]  [220/319]  eta: 0:00:21  lr: 0.005000  loss: 0.2835 (0.3904)  loss_classifier: 0.0420 (0.0796)  loss_box_reg: 0.0774 (0.1019)  loss_mask: 0.1300 (0.1908)  loss_objectness: 0.0029 (0.0130)  loss_rpn_box_reg: 0.0018 (0.0051)  time: 0.2118  data: 0.0034  max mem: 1507
# Epoch: [1]  [230/319]  eta: 0:00:18  lr: 0.005000  loss: 0.2661 (0.3863)  loss_classifier: 0.0422 (0.0787)  loss_box_reg: 0.0652 (0.1008)  loss_mask: 0.1217 (0.1891)  loss_objectness: 0.0029 (0.0127)  loss_rpn_box_reg: 0.0012 (0.0050)  time: 0.2008  data: 0.0035  max mem: 1507
# Epoch: [1]  [240/319]  eta: 0:00:16  lr: 0.005000  loss: 0.2305 (0.3853)  loss_classifier: 0.0393 (0.0776)  loss_box_reg: 0.0464 (0.1005)  loss_mask: 0.1239 (0.1898)  loss_objectness: 0.0019 (0.0123)  loss_rpn_box_reg: 0.0016 (0.0050)  time: 0.2055  data: 0.0035  max mem: 1507
# Epoch: [1]  [250/319]  eta: 0:00:14  lr: 0.005000  loss: 0.3010 (0.3893)  loss_classifier: 0.0388 (0.0775)  loss_box_reg: 0.0611 (0.1013)  loss_mask: 0.1808 (0.1935)  loss_objectness: 0.0021 (0.0121)  loss_rpn_box_reg: 0.0015 (0.0050)  time: 0.2188  data: 0.0036  max mem: 1507
# Epoch: [1]  [260/319]  eta: 0:00:12  lr: 0.005000  loss: 0.3749 (0.3932)  loss_classifier: 0.0604 (0.0786)  loss_box_reg: 0.0810 (0.1022)  loss_mask: 0.2465 (0.1953)  loss_objectness: 0.0059 (0.0119)  loss_rpn_box_reg: 0.0040 (0.0051)  time: 0.2264  data: 0.0036  max mem: 1507
# Epoch: [1]  [270/319]  eta: 0:00:10  lr: 0.005000  loss: 0.4287 (0.3924)  loss_classifier: 0.0715 (0.0780)  loss_box_reg: 0.0709 (0.1017)  loss_mask: 0.1842 (0.1959)  loss_objectness: 0.0065 (0.0118)  loss_rpn_box_reg: 0.0039 (0.0051)  time: 0.2218  data: 0.0035  max mem: 1507
# Epoch: [1]  [280/319]  eta: 0:00:08  lr: 0.005000  loss: 0.1989 (0.3868)  loss_classifier: 0.0310 (0.0765)  loss_box_reg: 0.0410 (0.0999)  loss_mask: 0.1348 (0.1940)  loss_objectness: 0.0023 (0.0115)  loss_rpn_box_reg: 0.0014 (0.0049)  time: 0.2030  data: 0.0033  max mem: 1507
# Epoch: [1]  [290/319]  eta: 0:00:06  lr: 0.005000  loss: 0.2316 (0.3892)  loss_classifier: 0.0307 (0.0778)  loss_box_reg: 0.0466 (0.1015)  loss_mask: 0.1270 (0.1934)  loss_objectness: 0.0014 (0.0115)  loss_rpn_box_reg: 0.0016 (0.0050)  time: 0.2158  data: 0.0035  max mem: 1507
# Epoch: [1]  [300/319]  eta: 0:00:04  lr: 0.005000  loss: 0.2349 (0.3889)  loss_classifier: 0.0399 (0.0778)  loss_box_reg: 0.0676 (0.1012)  loss_mask: 0.1325 (0.1938)  loss_objectness: 0.0025 (0.0112)  loss_rpn_box_reg: 0.0019 (0.0050)  time: 0.2232  data: 0.0036  max mem: 1507
# Epoch: [1]  [310/319]  eta: 0:00:01  lr: 0.005000  loss: 0.2255 (0.3886)  loss_classifier: 0.0264 (0.0778)  loss_box_reg: 0.0534 (0.1016)  loss_mask: 0.1456 (0.1933)  loss_objectness: 0.0022 (0.0109)  loss_rpn_box_reg: 0.0015 (0.0049)  time: 0.2082  data: 0.0036  max mem: 1507
# Epoch: [1]  [318/319]  eta: 0:00:00  lr: 0.005000  loss: 0.2179 (0.3864)  loss_classifier: 0.0264 (0.0773)  loss_box_reg: 0.0371 (0.1009)  loss_mask: 0.1456 (0.1924)  loss_objectness: 0.0011 (0.0108)  loss_rpn_box_reg: 0.0015 (0.0050)  time: 0.2011  data: 0.0034  max mem: 1507
# Epoch: [1] Total time: 0:01:08 (0.2134 s / it)
# creating index...
# index created!
# Test:  [  0/150]  eta: 0:01:29  model_time: 0.1308 (0.1308)  evaluator_time: 0.0632 (0.0632)  time: 0.5938  data: 0.3777  max mem: 1507
# Test:  [100/150]  eta: 0:00:06  model_time: 0.0783 (0.0890)  evaluator_time: 0.0227 (0.0357)  time: 0.1164  data: 0.0043  max mem: 1507
# Test:  [149/150]  eta: 0:00:00  model_time: 0.0737 (0.0903)  evaluator_time: 0.0217 (0.0372)  time: 0.1262  data: 0.0044  max mem: 1507
# Test: Total time: 0:00:20 (0.1388 s / it)
# Averaged stats: model_time: 0.0737 (0.0903)  evaluator_time: 0.0217 (0.0372)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.433
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.712
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.476
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.474
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.597
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.678
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.448
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.705
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.513
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.499
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.651
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.676
# Epoch: [2]  [  0/319]  eta: 0:03:43  lr: 0.005000  loss: 0.0931 (0.0931)  loss_classifier: 0.0146 (0.0146)  loss_box_reg: 0.0195 (0.0195)  loss_mask: 0.0526 (0.0526)  loss_objectness: 0.0062 (0.0062)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.7010  data: 0.4990  max mem: 1507
# Epoch: [2]  [ 10/319]  eta: 0:01:17  lr: 0.005000  loss: 0.1928 (0.2800)  loss_classifier: 0.0348 (0.0519)  loss_box_reg: 0.0508 (0.0772)  loss_mask: 0.1295 (0.1438)  loss_objectness: 0.0029 (0.0052)  loss_rpn_box_reg: 0.0018 (0.0020)  time: 0.2516  data: 0.0477  max mem: 1507
# Epoch: [2]  [ 20/319]  eta: 0:01:14  lr: 0.005000  loss: 0.2237 (0.3558)  loss_classifier: 0.0427 (0.0677)  loss_box_reg: 0.0571 (0.1089)  loss_mask: 0.1295 (0.1702)  loss_objectness: 0.0017 (0.0047)  loss_rpn_box_reg: 0.0019 (0.0043)  time: 0.2262  data: 0.0025  max mem: 1507
# Epoch: [2]  [ 30/319]  eta: 0:01:09  lr: 0.005000  loss: 0.3469 (0.4000)  loss_classifier: 0.0567 (0.0844)  loss_box_reg: 0.0935 (0.1192)  loss_mask: 0.1704 (0.1790)  loss_objectness: 0.0017 (0.0123)  loss_rpn_box_reg: 0.0025 (0.0051)  time: 0.2351  data: 0.0030  max mem: 1507
# Epoch: [2]  [ 40/319]  eta: 0:01:03  lr: 0.005000  loss: 0.3204 (0.3619)  loss_classifier: 0.0450 (0.0739)  loss_box_reg: 0.0622 (0.1024)  loss_mask: 0.1515 (0.1708)  loss_objectness: 0.0023 (0.0106)  loss_rpn_box_reg: 0.0019 (0.0042)  time: 0.2076  data: 0.0035  max mem: 1507
# Epoch: [2]  [ 50/319]  eta: 0:01:00  lr: 0.005000  loss: 0.1955 (0.3514)  loss_classifier: 0.0266 (0.0713)  loss_box_reg: 0.0398 (0.0994)  loss_mask: 0.1033 (0.1662)  loss_objectness: 0.0023 (0.0103)  loss_rpn_box_reg: 0.0021 (0.0042)  time: 0.1996  data: 0.0037  max mem: 1507
# Epoch: [2]  [ 60/319]  eta: 0:00:57  lr: 0.005000  loss: 0.2041 (0.3454)  loss_classifier: 0.0313 (0.0710)  loss_box_reg: 0.0485 (0.0980)  loss_mask: 0.0980 (0.1628)  loss_objectness: 0.0026 (0.0095)  loss_rpn_box_reg: 0.0016 (0.0042)  time: 0.2118  data: 0.0037  max mem: 1507
# Epoch: [2]  [ 70/319]  eta: 0:00:56  lr: 0.005000  loss: 0.2306 (0.3530)  loss_classifier: 0.0390 (0.0721)  loss_box_reg: 0.0527 (0.1035)  loss_mask: 0.1366 (0.1645)  loss_objectness: 0.0031 (0.0088)  loss_rpn_box_reg: 0.0013 (0.0040)  time: 0.2301  data: 0.0035  max mem: 1507
# Epoch: [2]  [ 80/319]  eta: 0:00:53  lr: 0.005000  loss: 0.2306 (0.3385)  loss_classifier: 0.0332 (0.0673)  loss_box_reg: 0.0370 (0.0970)  loss_mask: 0.1625 (0.1623)  loss_objectness: 0.0026 (0.0082)  loss_rpn_box_reg: 0.0015 (0.0037)  time: 0.2215  data: 0.0034  max mem: 1507
# Epoch: [2]  [ 90/319]  eta: 0:00:51  lr: 0.005000  loss: 0.2229 (0.3290)  loss_classifier: 0.0193 (0.0649)  loss_box_reg: 0.0319 (0.0925)  loss_mask: 0.1225 (0.1597)  loss_objectness: 0.0010 (0.0081)  loss_rpn_box_reg: 0.0009 (0.0037)  time: 0.2120  data: 0.0037  max mem: 1507
# Epoch: [2]  [100/319]  eta: 0:00:49  lr: 0.005000  loss: 0.2329 (0.3417)  loss_classifier: 0.0272 (0.0696)  loss_box_reg: 0.0412 (0.0949)  loss_mask: 0.1356 (0.1610)  loss_objectness: 0.0012 (0.0116)  loss_rpn_box_reg: 0.0011 (0.0046)  time: 0.2358  data: 0.0038  max mem: 1507
# Epoch: [2]  [110/319]  eta: 0:00:46  lr: 0.005000  loss: 0.2329 (0.3398)  loss_classifier: 0.0399 (0.0687)  loss_box_reg: 0.0614 (0.0919)  loss_mask: 0.1495 (0.1636)  loss_objectness: 0.0039 (0.0113)  loss_rpn_box_reg: 0.0019 (0.0044)  time: 0.2252  data: 0.0036  max mem: 1507
# Epoch: [2]  [120/319]  eta: 0:00:44  lr: 0.005000  loss: 0.2814 (0.3494)  loss_classifier: 0.0400 (0.0716)  loss_box_reg: 0.0454 (0.0944)  loss_mask: 0.1630 (0.1674)  loss_objectness: 0.0070 (0.0117)  loss_rpn_box_reg: 0.0022 (0.0044)  time: 0.2096  data: 0.0035  max mem: 1507
# Epoch: [2]  [130/319]  eta: 0:00:42  lr: 0.005000  loss: 0.2818 (0.3492)  loss_classifier: 0.0466 (0.0716)  loss_box_reg: 0.0788 (0.0954)  loss_mask: 0.1601 (0.1663)  loss_objectness: 0.0070 (0.0115)  loss_rpn_box_reg: 0.0041 (0.0045)  time: 0.2172  data: 0.0034  max mem: 1507
# Epoch: [2]  [140/319]  eta: 0:00:39  lr: 0.005000  loss: 0.2326 (0.3432)  loss_classifier: 0.0462 (0.0696)  loss_box_reg: 0.0474 (0.0938)  loss_mask: 0.1425 (0.1645)  loss_objectness: 0.0025 (0.0109)  loss_rpn_box_reg: 0.0035 (0.0044)  time: 0.2117  data: 0.0035  max mem: 1507
# Epoch: [2]  [150/319]  eta: 0:00:37  lr: 0.005000  loss: 0.1945 (0.3394)  loss_classifier: 0.0336 (0.0688)  loss_box_reg: 0.0474 (0.0925)  loss_mask: 0.1144 (0.1634)  loss_objectness: 0.0019 (0.0104)  loss_rpn_box_reg: 0.0015 (0.0042)  time: 0.1994  data: 0.0035  max mem: 1507
# Epoch: [2]  [160/319]  eta: 0:00:34  lr: 0.005000  loss: 0.1945 (0.3345)  loss_classifier: 0.0336 (0.0678)  loss_box_reg: 0.0498 (0.0917)  loss_mask: 0.1096 (0.1608)  loss_objectness: 0.0027 (0.0100)  loss_rpn_box_reg: 0.0014 (0.0042)  time: 0.2064  data: 0.0038  max mem: 1507
# Epoch: [2]  [170/319]  eta: 0:00:32  lr: 0.005000  loss: 0.2090 (0.3421)  loss_classifier: 0.0337 (0.0711)  loss_box_reg: 0.0581 (0.0948)  loss_mask: 0.1228 (0.1622)  loss_objectness: 0.0016 (0.0098)  loss_rpn_box_reg: 0.0021 (0.0042)  time: 0.2167  data: 0.0038  max mem: 1507
# Epoch: [2]  [180/319]  eta: 0:00:30  lr: 0.005000  loss: 0.2215 (0.3467)  loss_classifier: 0.0661 (0.0729)  loss_box_reg: 0.0607 (0.0977)  loss_mask: 0.1273 (0.1623)  loss_objectness: 0.0017 (0.0095)  loss_rpn_box_reg: 0.0041 (0.0042)  time: 0.2319  data: 0.0035  max mem: 1507
# Epoch: [2]  [190/319]  eta: 0:00:28  lr: 0.005000  loss: 0.2619 (0.3467)  loss_classifier: 0.0583 (0.0726)  loss_box_reg: 0.0607 (0.0984)  loss_mask: 0.1319 (0.1618)  loss_objectness: 0.0018 (0.0097)  loss_rpn_box_reg: 0.0031 (0.0042)  time: 0.2326  data: 0.0036  max mem: 1507
# Epoch: [2]  [200/319]  eta: 0:00:26  lr: 0.005000  loss: 0.2407 (0.3438)  loss_classifier: 0.0457 (0.0715)  loss_box_reg: 0.0550 (0.0969)  loss_mask: 0.1273 (0.1618)  loss_objectness: 0.0025 (0.0094)  loss_rpn_box_reg: 0.0018 (0.0041)  time: 0.2130  data: 0.0038  max mem: 1507
# Epoch: [2]  [210/319]  eta: 0:00:23  lr: 0.005000  loss: 0.2200 (0.3412)  loss_classifier: 0.0457 (0.0722)  loss_box_reg: 0.0550 (0.0959)  loss_mask: 0.0987 (0.1597)  loss_objectness: 0.0033 (0.0093)  loss_rpn_box_reg: 0.0019 (0.0041)  time: 0.2047  data: 0.0037  max mem: 1507
# Epoch: [2]  [220/319]  eta: 0:00:21  lr: 0.005000  loss: 0.2947 (0.3454)  loss_classifier: 0.0622 (0.0733)  loss_box_reg: 0.0901 (0.0986)  loss_mask: 0.1238 (0.1602)  loss_objectness: 0.0033 (0.0090)  loss_rpn_box_reg: 0.0031 (0.0041)  time: 0.2230  data: 0.0038  max mem: 1507
# Epoch: [2]  [230/319]  eta: 0:00:19  lr: 0.005000  loss: 0.4125 (0.3530)  loss_classifier: 0.0687 (0.0743)  loss_box_reg: 0.1093 (0.1015)  loss_mask: 0.1851 (0.1640)  loss_objectness: 0.0020 (0.0089)  loss_rpn_box_reg: 0.0028 (0.0043)  time: 0.2360  data: 0.0038  max mem: 1507
# Epoch: [2]  [240/319]  eta: 0:00:17  lr: 0.005000  loss: 0.3048 (0.3542)  loss_classifier: 0.0322 (0.0736)  loss_box_reg: 0.0634 (0.1010)  loss_mask: 0.1706 (0.1667)  loss_objectness: 0.0017 (0.0088)  loss_rpn_box_reg: 0.0022 (0.0042)  time: 0.2185  data: 0.0035  max mem: 1507
# Epoch: [2]  [250/319]  eta: 0:00:15  lr: 0.005000  loss: 0.2733 (0.3529)  loss_classifier: 0.0358 (0.0725)  loss_box_reg: 0.0504 (0.0999)  loss_mask: 0.1704 (0.1679)  loss_objectness: 0.0016 (0.0085)  loss_rpn_box_reg: 0.0012 (0.0041)  time: 0.2023  data: 0.0038  max mem: 1507
# Epoch: [2]  [260/319]  eta: 0:00:12  lr: 0.005000  loss: 0.2575 (0.3552)  loss_classifier: 0.0514 (0.0736)  loss_box_reg: 0.0592 (0.1015)  loss_mask: 0.1595 (0.1676)  loss_objectness: 0.0019 (0.0084)  loss_rpn_box_reg: 0.0020 (0.0041)  time: 0.2162  data: 0.0040  max mem: 1507
# Epoch: [2]  [270/319]  eta: 0:00:10  lr: 0.005000  loss: 0.2252 (0.3539)  loss_classifier: 0.0421 (0.0734)  loss_box_reg: 0.0549 (0.1010)  loss_mask: 0.1416 (0.1672)  loss_objectness: 0.0019 (0.0083)  loss_rpn_box_reg: 0.0019 (0.0041)  time: 0.2212  data: 0.0039  max mem: 1507
# Epoch: [2]  [280/319]  eta: 0:00:08  lr: 0.005000  loss: 0.2080 (0.3504)  loss_classifier: 0.0293 (0.0723)  loss_box_reg: 0.0452 (0.0996)  loss_mask: 0.1416 (0.1665)  loss_objectness: 0.0005 (0.0080)  loss_rpn_box_reg: 0.0010 (0.0041)  time: 0.2013  data: 0.0038  max mem: 1507
# Epoch: [2]  [290/319]  eta: 0:00:06  lr: 0.005000  loss: 0.1888 (0.3486)  loss_classifier: 0.0214 (0.0718)  loss_box_reg: 0.0408 (0.0987)  loss_mask: 0.1309 (0.1660)  loss_objectness: 0.0005 (0.0079)  loss_rpn_box_reg: 0.0010 (0.0041)  time: 0.2015  data: 0.0036  max mem: 1507
# Epoch: [2]  [300/319]  eta: 0:00:04  lr: 0.005000  loss: 0.2129 (0.3451)  loss_classifier: 0.0295 (0.0707)  loss_box_reg: 0.0397 (0.0973)  loss_mask: 0.1108 (0.1652)  loss_objectness: 0.0007 (0.0078)  loss_rpn_box_reg: 0.0011 (0.0041)  time: 0.2048  data: 0.0034  max mem: 1507
# Epoch: [2]  [310/319]  eta: 0:00:01  lr: 0.005000  loss: 0.1716 (0.3433)  loss_classifier: 0.0250 (0.0703)  loss_box_reg: 0.0308 (0.0966)  loss_mask: 0.1100 (0.1646)  loss_objectness: 0.0018 (0.0077)  loss_rpn_box_reg: 0.0013 (0.0041)  time: 0.2057  data: 0.0033  max mem: 1507
# Epoch: [2]  [318/319]  eta: 0:00:00  lr: 0.005000  loss: 0.2086 (0.3422)  loss_classifier: 0.0274 (0.0698)  loss_box_reg: 0.0473 (0.0960)  loss_mask: 0.1274 (0.1646)  loss_objectness: 0.0019 (0.0076)  loss_rpn_box_reg: 0.0014 (0.0041)  time: 0.2049  data: 0.0033  max mem: 1507
# Epoch: [2] Total time: 0:01:09 (0.2171 s / it)
# creating index...
# index created!
# Test:  [  0/150]  eta: 0:01:16  model_time: 0.0876 (0.0876)  evaluator_time: 0.0223 (0.0223)  time: 0.5103  data: 0.3787  max mem: 1507
# Test:  [100/150]  eta: 0:00:05  model_time: 0.0598 (0.0720)  evaluator_time: 0.0132 (0.0206)  time: 0.0979  data: 0.0042  max mem: 1507
# Test:  [149/150]  eta: 0:00:00  model_time: 0.0601 (0.0744)  evaluator_time: 0.0125 (0.0229)  time: 0.0979  data: 0.0045  max mem: 1507
# Test: Total time: 0:00:16 (0.1078 s / it)
# Averaged stats: model_time: 0.0601 (0.0744)  evaluator_time: 0.0125 (0.0229)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.545
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.777
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.641
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.156
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.602
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.658
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.693
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.505
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.727
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.491
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.762
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.547
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.638
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.669
# Epoch: [3]  [  0/319]  eta: 0:04:01  lr: 0.000500  loss: 0.1245 (0.1245)  loss_classifier: 0.0274 (0.0274)  loss_box_reg: 0.0481 (0.0481)  loss_mask: 0.0481 (0.0481)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0005)  time: 0.7567  data: 0.4873  max mem: 1507
# Epoch: [3]  [ 10/319]  eta: 0:01:25  lr: 0.000500  loss: 0.2481 (0.3227)  loss_classifier: 0.0266 (0.0558)  loss_box_reg: 0.0387 (0.0956)  loss_mask: 0.0990 (0.1657)  loss_objectness: 0.0005 (0.0026)  loss_rpn_box_reg: 0.0014 (0.0030)  time: 0.2752  data: 0.0472  max mem: 1507
# Epoch: [3]  [ 20/319]  eta: 0:01:13  lr: 0.000500  loss: 0.2019 (0.2998)  loss_classifier: 0.0266 (0.0537)  loss_box_reg: 0.0353 (0.0903)  loss_mask: 0.1115 (0.1486)  loss_objectness: 0.0010 (0.0024)  loss_rpn_box_reg: 0.0016 (0.0049)  time: 0.2213  data: 0.0029  max mem: 1507
# Epoch: [3]  [ 30/319]  eta: 0:01:10  lr: 0.000500  loss: 0.2019 (0.3461)  loss_classifier: 0.0290 (0.0723)  loss_box_reg: 0.0277 (0.1031)  loss_mask: 0.1328 (0.1582)  loss_objectness: 0.0010 (0.0075)  loss_rpn_box_reg: 0.0020 (0.0050)  time: 0.2274  data: 0.0033  max mem: 1507
# Epoch: [3]  [ 40/319]  eta: 0:01:05  lr: 0.000500  loss: 0.2029 (0.3297)  loss_classifier: 0.0256 (0.0671)  loss_box_reg: 0.0274 (0.0938)  loss_mask: 0.1218 (0.1575)  loss_objectness: 0.0014 (0.0067)  loss_rpn_box_reg: 0.0018 (0.0045)  time: 0.2229  data: 0.0036  max mem: 1507
# Epoch: [3]  [ 50/319]  eta: 0:01:01  lr: 0.000500  loss: 0.2056 (0.3159)  loss_classifier: 0.0379 (0.0640)  loss_box_reg: 0.0274 (0.0893)  loss_mask: 0.1099 (0.1526)  loss_objectness: 0.0016 (0.0060)  loss_rpn_box_reg: 0.0018 (0.0040)  time: 0.2060  data: 0.0035  max mem: 1507
# Epoch: [3]  [ 60/319]  eta: 0:00:58  lr: 0.000500  loss: 0.2438 (0.3130)  loss_classifier: 0.0419 (0.0627)  loss_box_reg: 0.0443 (0.0863)  loss_mask: 0.1204 (0.1548)  loss_objectness: 0.0008 (0.0054)  loss_rpn_box_reg: 0.0014 (0.0037)  time: 0.2068  data: 0.0035  max mem: 1507
# Epoch: [3]  [ 70/319]  eta: 0:00:56  lr: 0.000500  loss: 0.2438 (0.3180)  loss_classifier: 0.0309 (0.0638)  loss_box_reg: 0.0443 (0.0863)  loss_mask: 0.1713 (0.1585)  loss_objectness: 0.0016 (0.0054)  loss_rpn_box_reg: 0.0013 (0.0039)  time: 0.2166  data: 0.0034  max mem: 1507
# Epoch: [3]  [ 80/319]  eta: 0:00:53  lr: 0.000500  loss: 0.1896 (0.3038)  loss_classifier: 0.0255 (0.0600)  loss_box_reg: 0.0317 (0.0816)  loss_mask: 0.1037 (0.1536)  loss_objectness: 0.0011 (0.0050)  loss_rpn_box_reg: 0.0007 (0.0036)  time: 0.2205  data: 0.0034  max mem: 1507
# Epoch: [3]  [ 90/319]  eta: 0:00:51  lr: 0.000500  loss: 0.1718 (0.3035)  loss_classifier: 0.0213 (0.0610)  loss_box_reg: 0.0334 (0.0828)  loss_mask: 0.0979 (0.1515)  loss_objectness: 0.0008 (0.0048)  loss_rpn_box_reg: 0.0005 (0.0035)  time: 0.2218  data: 0.0034  max mem: 1507
# Epoch: [3]  [100/319]  eta: 0:00:49  lr: 0.000500  loss: 0.1805 (0.2963)  loss_classifier: 0.0213 (0.0591)  loss_box_reg: 0.0375 (0.0805)  loss_mask: 0.1109 (0.1490)  loss_objectness: 0.0013 (0.0045)  loss_rpn_box_reg: 0.0007 (0.0033)  time: 0.2235  data: 0.0034  max mem: 1507
# Epoch: [3]  [110/319]  eta: 0:00:46  lr: 0.000500  loss: 0.1805 (0.2892)  loss_classifier: 0.0154 (0.0567)  loss_box_reg: 0.0375 (0.0773)  loss_mask: 0.1213 (0.1479)  loss_objectness: 0.0006 (0.0042)  loss_rpn_box_reg: 0.0007 (0.0031)  time: 0.2160  data: 0.0039  max mem: 1507
# Epoch: [3]  [120/319]  eta: 0:00:44  lr: 0.000500  loss: 0.1555 (0.2815)  loss_classifier: 0.0185 (0.0542)  loss_box_reg: 0.0261 (0.0743)  loss_mask: 0.1213 (0.1460)  loss_objectness: 0.0005 (0.0040)  loss_rpn_box_reg: 0.0007 (0.0030)  time: 0.2098  data: 0.0039  max mem: 1507
# Epoch: [3]  [130/319]  eta: 0:00:41  lr: 0.000500  loss: 0.1839 (0.2868)  loss_classifier: 0.0246 (0.0534)  loss_box_reg: 0.0299 (0.0734)  loss_mask: 0.1201 (0.1531)  loss_objectness: 0.0005 (0.0040)  loss_rpn_box_reg: 0.0009 (0.0030)  time: 0.2062  data: 0.0035  max mem: 1507
# Epoch: [3]  [140/319]  eta: 0:00:39  lr: 0.000500  loss: 0.2574 (0.2903)  loss_classifier: 0.0272 (0.0559)  loss_box_reg: 0.0389 (0.0743)  loss_mask: 0.1352 (0.1526)  loss_objectness: 0.0020 (0.0044)  loss_rpn_box_reg: 0.0019 (0.0030)  time: 0.2153  data: 0.0034  max mem: 1507
# Epoch: [3]  [150/319]  eta: 0:00:37  lr: 0.000500  loss: 0.1811 (0.2850)  loss_classifier: 0.0296 (0.0544)  loss_box_reg: 0.0386 (0.0724)  loss_mask: 0.1110 (0.1509)  loss_objectness: 0.0017 (0.0044)  loss_rpn_box_reg: 0.0018 (0.0029)  time: 0.2182  data: 0.0034  max mem: 1507
# Epoch: [3]  [160/319]  eta: 0:00:35  lr: 0.000500  loss: 0.2492 (0.2854)  loss_classifier: 0.0404 (0.0547)  loss_box_reg: 0.0411 (0.0731)  loss_mask: 0.1243 (0.1501)  loss_objectness: 0.0018 (0.0046)  loss_rpn_box_reg: 0.0017 (0.0029)  time: 0.2185  data: 0.0033  max mem: 1507
# Epoch: [3]  [170/319]  eta: 0:00:32  lr: 0.000500  loss: 0.2235 (0.2809)  loss_classifier: 0.0433 (0.0539)  loss_box_reg: 0.0411 (0.0720)  loss_mask: 0.1155 (0.1477)  loss_objectness: 0.0026 (0.0045)  loss_rpn_box_reg: 0.0016 (0.0028)  time: 0.2255  data: 0.0034  max mem: 1507
# Epoch: [3]  [180/319]  eta: 0:00:31  lr: 0.000500  loss: 0.1478 (0.2852)  loss_classifier: 0.0268 (0.0566)  loss_box_reg: 0.0237 (0.0726)  loss_mask: 0.1077 (0.1475)  loss_objectness: 0.0024 (0.0053)  loss_rpn_box_reg: 0.0010 (0.0031)  time: 0.2429  data: 0.0035  max mem: 1507
# Epoch: [3]  [190/319]  eta: 0:00:28  lr: 0.000500  loss: 0.1466 (0.2815)  loss_classifier: 0.0173 (0.0560)  loss_box_reg: 0.0200 (0.0712)  loss_mask: 0.1077 (0.1461)  loss_objectness: 0.0024 (0.0052)  loss_rpn_box_reg: 0.0010 (0.0030)  time: 0.2306  data: 0.0035  max mem: 1507
# Epoch: [3]  [200/319]  eta: 0:00:26  lr: 0.000500  loss: 0.2194 (0.2855)  loss_classifier: 0.0337 (0.0571)  loss_box_reg: 0.0336 (0.0723)  loss_mask: 0.1302 (0.1479)  loss_objectness: 0.0018 (0.0052)  loss_rpn_box_reg: 0.0010 (0.0031)  time: 0.2155  data: 0.0035  max mem: 1507
# Epoch: [3]  [210/319]  eta: 0:00:24  lr: 0.000500  loss: 0.2194 (0.2831)  loss_classifier: 0.0407 (0.0562)  loss_box_reg: 0.0369 (0.0716)  loss_mask: 0.1338 (0.1471)  loss_objectness: 0.0032 (0.0052)  loss_rpn_box_reg: 0.0024 (0.0030)  time: 0.2213  data: 0.0033  max mem: 1507
# Epoch: [3]  [220/319]  eta: 0:00:21  lr: 0.000500  loss: 0.1982 (0.2799)  loss_classifier: 0.0287 (0.0552)  loss_box_reg: 0.0369 (0.0702)  loss_mask: 0.1159 (0.1464)  loss_objectness: 0.0025 (0.0051)  loss_rpn_box_reg: 0.0019 (0.0030)  time: 0.2123  data: 0.0034  max mem: 1507
# Epoch: [3]  [230/319]  eta: 0:00:19  lr: 0.000500  loss: 0.1603 (0.2749)  loss_classifier: 0.0267 (0.0537)  loss_box_reg: 0.0315 (0.0683)  loss_mask: 0.0978 (0.1449)  loss_objectness: 0.0009 (0.0050)  loss_rpn_box_reg: 0.0010 (0.0029)  time: 0.1988  data: 0.0036  max mem: 1507
# Epoch: [3]  [240/319]  eta: 0:00:17  lr: 0.000500  loss: 0.1534 (0.2720)  loss_classifier: 0.0142 (0.0531)  loss_box_reg: 0.0233 (0.0673)  loss_mask: 0.0977 (0.1438)  loss_objectness: 0.0008 (0.0049)  loss_rpn_box_reg: 0.0007 (0.0029)  time: 0.1929  data: 0.0035  max mem: 1507
# Epoch: [3]  [250/319]  eta: 0:00:15  lr: 0.000500  loss: 0.1585 (0.2681)  loss_classifier: 0.0160 (0.0521)  loss_box_reg: 0.0186 (0.0662)  loss_mask: 0.0977 (0.1422)  loss_objectness: 0.0013 (0.0048)  loss_rpn_box_reg: 0.0006 (0.0028)  time: 0.2011  data: 0.0036  max mem: 1507
# Epoch: [3]  [260/319]  eta: 0:00:12  lr: 0.000500  loss: 0.1670 (0.2668)  loss_classifier: 0.0199 (0.0515)  loss_box_reg: 0.0235 (0.0657)  loss_mask: 0.1107 (0.1419)  loss_objectness: 0.0017 (0.0049)  loss_rpn_box_reg: 0.0012 (0.0028)  time: 0.2059  data: 0.0034  max mem: 1507
# Epoch: [3]  [270/319]  eta: 0:00:10  lr: 0.000500  loss: 0.1815 (0.2633)  loss_classifier: 0.0199 (0.0505)  loss_box_reg: 0.0261 (0.0645)  loss_mask: 0.1174 (0.1408)  loss_objectness: 0.0007 (0.0047)  loss_rpn_box_reg: 0.0009 (0.0028)  time: 0.2041  data: 0.0034  max mem: 1507
# Epoch: [3]  [280/319]  eta: 0:00:08  lr: 0.000500  loss: 0.1480 (0.2597)  loss_classifier: 0.0173 (0.0495)  loss_box_reg: 0.0234 (0.0631)  loss_mask: 0.0995 (0.1398)  loss_objectness: 0.0006 (0.0046)  loss_rpn_box_reg: 0.0007 (0.0027)  time: 0.1951  data: 0.0037  max mem: 1507
# Epoch: [3]  [290/319]  eta: 0:00:06  lr: 0.000500  loss: 0.1486 (0.2580)  loss_classifier: 0.0188 (0.0489)  loss_box_reg: 0.0265 (0.0624)  loss_mask: 0.1059 (0.1395)  loss_objectness: 0.0008 (0.0045)  loss_rpn_box_reg: 0.0008 (0.0027)  time: 0.1981  data: 0.0038  max mem: 1507
# Epoch: [3]  [300/319]  eta: 0:00:04  lr: 0.000500  loss: 0.1651 (0.2551)  loss_classifier: 0.0181 (0.0480)  loss_box_reg: 0.0228 (0.0615)  loss_mask: 0.1099 (0.1386)  loss_objectness: 0.0007 (0.0044)  loss_rpn_box_reg: 0.0009 (0.0026)  time: 0.2022  data: 0.0036  max mem: 1507
# Epoch: [3]  [310/319]  eta: 0:00:01  lr: 0.000500  loss: 0.1688 (0.2538)  loss_classifier: 0.0181 (0.0476)  loss_box_reg: 0.0192 (0.0607)  loss_mask: 0.1201 (0.1385)  loss_objectness: 0.0007 (0.0044)  loss_rpn_box_reg: 0.0006 (0.0026)  time: 0.2018  data: 0.0034  max mem: 1507
# Epoch: [3]  [318/319]  eta: 0:00:00  lr: 0.000500  loss: 0.1777 (0.2524)  loss_classifier: 0.0243 (0.0473)  loss_box_reg: 0.0309 (0.0604)  loss_mask: 0.1052 (0.1378)  loss_objectness: 0.0008 (0.0043)  loss_rpn_box_reg: 0.0009 (0.0026)  time: 0.2116  data: 0.0033  max mem: 1507
# Epoch: [3] Total time: 0:01:08 (0.2155 s / it)
# creating index...
# index created!
# Test:  [  0/150]  eta: 0:01:11  model_time: 0.0792 (0.0792)  evaluator_time: 0.0197 (0.0197)  time: 0.4750  data: 0.3539  max mem: 1507
# Test:  [100/150]  eta: 0:00:04  model_time: 0.0592 (0.0669)  evaluator_time: 0.0111 (0.0162)  time: 0.0856  data: 0.0045  max mem: 1507
# Test:  [149/150]  eta: 0:00:00  model_time: 0.0578 (0.0684)  evaluator_time: 0.0107 (0.0179)  time: 0.0888  data: 0.0041  max mem: 1507
# Test: Total time: 0:00:14 (0.0962 s / it)
# Averaged stats: model_time: 0.0578 (0.0684)  evaluator_time: 0.0107 (0.0179)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.595
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.784
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.658
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.234
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.736
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.486
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.781
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.547
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.776
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.617
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.607
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.660
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.679
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.718
# Epoch: [4]  [  0/319]  eta: 0:03:18  lr: 0.000500  loss: 0.1847 (0.1847)  loss_classifier: 0.0260 (0.0260)  loss_box_reg: 0.0353 (0.0353)  loss_mask: 0.1220 (0.1220)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0012 (0.0012)  time: 0.6209  data: 0.3732  max mem: 1507
# Epoch: [4]  [ 10/319]  eta: 0:01:25  lr: 0.000500  loss: 0.1356 (0.2530)  loss_classifier: 0.0174 (0.0646)  loss_box_reg: 0.0215 (0.0580)  loss_mask: 0.1035 (0.1126)  loss_objectness: 0.0005 (0.0114)  loss_rpn_box_reg: 0.0010 (0.0063)  time: 0.2766  data: 0.0372  max mem: 1507
# Epoch: [4]  [ 20/319]  eta: 0:01:12  lr: 0.000500  loss: 0.1487 (0.2328)  loss_classifier: 0.0174 (0.0470)  loss_box_reg: 0.0239 (0.0499)  loss_mask: 0.1088 (0.1229)  loss_objectness: 0.0005 (0.0088)  loss_rpn_box_reg: 0.0009 (0.0042)  time: 0.2218  data: 0.0032  max mem: 1507
# Epoch: [4]  [ 30/319]  eta: 0:01:05  lr: 0.000500  loss: 0.2115 (0.2246)  loss_classifier: 0.0193 (0.0440)  loss_box_reg: 0.0239 (0.0477)  loss_mask: 0.1193 (0.1227)  loss_objectness: 0.0012 (0.0069)  loss_rpn_box_reg: 0.0008 (0.0033)  time: 0.1994  data: 0.0031  max mem: 1507
# Epoch: [4]  [ 40/319]  eta: 0:01:01  lr: 0.000500  loss: 0.1462 (0.2123)  loss_classifier: 0.0168 (0.0387)  loss_box_reg: 0.0166 (0.0433)  loss_mask: 0.0987 (0.1218)  loss_objectness: 0.0012 (0.0056)  loss_rpn_box_reg: 0.0006 (0.0028)  time: 0.1978  data: 0.0034  max mem: 1507
# Epoch: [4]  [ 50/319]  eta: 0:00:57  lr: 0.000500  loss: 0.1444 (0.2047)  loss_classifier: 0.0160 (0.0362)  loss_box_reg: 0.0150 (0.0408)  loss_mask: 0.0987 (0.1202)  loss_objectness: 0.0009 (0.0050)  loss_rpn_box_reg: 0.0005 (0.0025)  time: 0.1959  data: 0.0034  max mem: 1507
# Epoch: [4]  [ 60/319]  eta: 0:00:56  lr: 0.000500  loss: 0.2175 (0.2169)  loss_classifier: 0.0305 (0.0387)  loss_box_reg: 0.0459 (0.0445)  loss_mask: 0.1228 (0.1267)  loss_objectness: 0.0009 (0.0046)  loss_rpn_box_reg: 0.0006 (0.0024)  time: 0.2138  data: 0.0036  max mem: 1507
# Epoch: [4]  [ 70/319]  eta: 0:00:53  lr: 0.000500  loss: 0.2457 (0.2193)  loss_classifier: 0.0305 (0.0391)  loss_box_reg: 0.0559 (0.0467)  loss_mask: 0.1295 (0.1271)  loss_objectness: 0.0014 (0.0042)  loss_rpn_box_reg: 0.0010 (0.0022)  time: 0.2217  data: 0.0036  max mem: 1507
# Epoch: [4]  [ 80/319]  eta: 0:00:52  lr: 0.000500  loss: 0.1433 (0.2195)  loss_classifier: 0.0187 (0.0401)  loss_box_reg: 0.0311 (0.0481)  loss_mask: 0.1016 (0.1249)  loss_objectness: 0.0014 (0.0041)  loss_rpn_box_reg: 0.0007 (0.0022)  time: 0.2203  data: 0.0036  max mem: 1507
# Epoch: [4]  [ 90/319]  eta: 0:00:50  lr: 0.000500  loss: 0.1343 (0.2172)  loss_classifier: 0.0120 (0.0396)  loss_box_reg: 0.0302 (0.0480)  loss_mask: 0.0935 (0.1238)  loss_objectness: 0.0009 (0.0037)  loss_rpn_box_reg: 0.0005 (0.0021)  time: 0.2255  data: 0.0038  max mem: 1507
# Epoch: [4]  [100/319]  eta: 0:00:47  lr: 0.000500  loss: 0.1597 (0.2209)  loss_classifier: 0.0195 (0.0392)  loss_box_reg: 0.0312 (0.0492)  loss_mask: 0.1043 (0.1269)  loss_objectness: 0.0005 (0.0034)  loss_rpn_box_reg: 0.0007 (0.0021)  time: 0.2177  data: 0.0040  max mem: 1507
# Epoch: [4]  [110/319]  eta: 0:00:45  lr: 0.000500  loss: 0.2385 (0.2263)  loss_classifier: 0.0359 (0.0399)  loss_box_reg: 0.0437 (0.0522)  loss_mask: 0.1407 (0.1287)  loss_objectness: 0.0008 (0.0033)  loss_rpn_box_reg: 0.0012 (0.0021)  time: 0.2255  data: 0.0037  max mem: 1507
# Epoch: [4]  [120/319]  eta: 0:00:43  lr: 0.000500  loss: 0.2700 (0.2342)  loss_classifier: 0.0374 (0.0416)  loss_box_reg: 0.0572 (0.0554)  loss_mask: 0.1452 (0.1313)  loss_objectness: 0.0022 (0.0036)  loss_rpn_box_reg: 0.0013 (0.0021)  time: 0.2290  data: 0.0034  max mem: 1507
# Epoch: [4]  [130/319]  eta: 0:00:41  lr: 0.000500  loss: 0.1637 (0.2318)  loss_classifier: 0.0322 (0.0407)  loss_box_reg: 0.0300 (0.0549)  loss_mask: 0.1107 (0.1304)  loss_objectness: 0.0014 (0.0035)  loss_rpn_box_reg: 0.0021 (0.0022)  time: 0.2189  data: 0.0033  max mem: 1507
# Epoch: [4]  [140/319]  eta: 0:00:39  lr: 0.000500  loss: 0.1341 (0.2331)  loss_classifier: 0.0186 (0.0412)  loss_box_reg: 0.0220 (0.0563)  loss_mask: 0.0949 (0.1301)  loss_objectness: 0.0005 (0.0034)  loss_rpn_box_reg: 0.0012 (0.0022)  time: 0.2170  data: 0.0034  max mem: 1507
# Epoch: [4]  [150/319]  eta: 0:00:37  lr: 0.000500  loss: 0.1533 (0.2306)  loss_classifier: 0.0174 (0.0405)  loss_box_reg: 0.0220 (0.0553)  loss_mask: 0.1087 (0.1294)  loss_objectness: 0.0006 (0.0033)  loss_rpn_box_reg: 0.0009 (0.0021)  time: 0.2202  data: 0.0039  max mem: 1507
# Epoch: [4]  [160/319]  eta: 0:00:34  lr: 0.000500  loss: 0.1539 (0.2290)  loss_classifier: 0.0188 (0.0400)  loss_box_reg: 0.0261 (0.0542)  loss_mask: 0.1116 (0.1294)  loss_objectness: 0.0006 (0.0033)  loss_rpn_box_reg: 0.0006 (0.0020)  time: 0.2169  data: 0.0040  max mem: 1507
# Epoch: [4]  [170/319]  eta: 0:00:32  lr: 0.000500  loss: 0.1539 (0.2309)  loss_classifier: 0.0190 (0.0403)  loss_box_reg: 0.0246 (0.0551)  loss_mask: 0.1116 (0.1301)  loss_objectness: 0.0007 (0.0033)  loss_rpn_box_reg: 0.0006 (0.0021)  time: 0.2166  data: 0.0038  max mem: 1507
# Epoch: [4]  [180/319]  eta: 0:00:30  lr: 0.000500  loss: 0.1639 (0.2335)  loss_classifier: 0.0345 (0.0413)  loss_box_reg: 0.0224 (0.0553)  loss_mask: 0.1189 (0.1315)  loss_objectness: 0.0007 (0.0033)  loss_rpn_box_reg: 0.0005 (0.0021)  time: 0.2261  data: 0.0038  max mem: 1507
# Epoch: [4]  [190/319]  eta: 0:00:28  lr: 0.000500  loss: 0.2066 (0.2329)  loss_classifier: 0.0245 (0.0410)  loss_box_reg: 0.0337 (0.0548)  loss_mask: 0.1448 (0.1319)  loss_objectness: 0.0009 (0.0032)  loss_rpn_box_reg: 0.0010 (0.0021)  time: 0.2218  data: 0.0036  max mem: 1507
# Epoch: [4]  [200/319]  eta: 0:00:26  lr: 0.000500  loss: 0.1821 (0.2306)  loss_classifier: 0.0203 (0.0403)  loss_box_reg: 0.0242 (0.0541)  loss_mask: 0.1079 (0.1311)  loss_objectness: 0.0008 (0.0031)  loss_rpn_box_reg: 0.0008 (0.0020)  time: 0.2077  data: 0.0035  max mem: 1507
# Epoch: [4]  [210/319]  eta: 0:00:23  lr: 0.000500  loss: 0.1660 (0.2309)  loss_classifier: 0.0191 (0.0408)  loss_box_reg: 0.0206 (0.0540)  loss_mask: 0.1129 (0.1309)  loss_objectness: 0.0004 (0.0031)  loss_rpn_box_reg: 0.0007 (0.0021)  time: 0.2068  data: 0.0034  max mem: 1507
# Epoch: [4]  [220/319]  eta: 0:00:21  lr: 0.000500  loss: 0.1486 (0.2302)  loss_classifier: 0.0191 (0.0398)  loss_box_reg: 0.0246 (0.0528)  loss_mask: 0.1078 (0.1325)  loss_objectness: 0.0006 (0.0030)  loss_rpn_box_reg: 0.0007 (0.0021)  time: 0.2013  data: 0.0034  max mem: 1507
# Epoch: [4]  [230/319]  eta: 0:00:19  lr: 0.000500  loss: 0.1252 (0.2277)  loss_classifier: 0.0145 (0.0395)  loss_box_reg: 0.0222 (0.0522)  loss_mask: 0.0893 (0.1309)  loss_objectness: 0.0007 (0.0030)  loss_rpn_box_reg: 0.0006 (0.0021)  time: 0.2015  data: 0.0034  max mem: 1507
# Epoch: [4]  [240/319]  eta: 0:00:17  lr: 0.000500  loss: 0.1118 (0.2257)  loss_classifier: 0.0158 (0.0391)  loss_box_reg: 0.0180 (0.0518)  loss_mask: 0.0795 (0.1298)  loss_objectness: 0.0005 (0.0029)  loss_rpn_box_reg: 0.0010 (0.0020)  time: 0.2074  data: 0.0034  max mem: 1507
# Epoch: [4]  [250/319]  eta: 0:00:14  lr: 0.000500  loss: 0.1158 (0.2229)  loss_classifier: 0.0136 (0.0381)  loss_box_reg: 0.0180 (0.0506)  loss_mask: 0.0870 (0.1292)  loss_objectness: 0.0004 (0.0029)  loss_rpn_box_reg: 0.0008 (0.0020)  time: 0.2001  data: 0.0036  max mem: 1507
# Epoch: [4]  [260/319]  eta: 0:00:12  lr: 0.000500  loss: 0.1534 (0.2231)  loss_classifier: 0.0161 (0.0385)  loss_box_reg: 0.0221 (0.0510)  loss_mask: 0.0991 (0.1287)  loss_objectness: 0.0006 (0.0029)  loss_rpn_box_reg: 0.0006 (0.0020)  time: 0.2116  data: 0.0035  max mem: 1507
# Epoch: [4]  [270/319]  eta: 0:00:10  lr: 0.000500  loss: 0.1588 (0.2213)  loss_classifier: 0.0161 (0.0382)  loss_box_reg: 0.0212 (0.0507)  loss_mask: 0.0991 (0.1276)  loss_objectness: 0.0008 (0.0029)  loss_rpn_box_reg: 0.0007 (0.0020)  time: 0.2150  data: 0.0034  max mem: 1507
# Epoch: [4]  [280/319]  eta: 0:00:08  lr: 0.000500  loss: 0.1543 (0.2257)  loss_classifier: 0.0161 (0.0397)  loss_box_reg: 0.0238 (0.0519)  loss_mask: 0.1063 (0.1292)  loss_objectness: 0.0009 (0.0029)  loss_rpn_box_reg: 0.0009 (0.0021)  time: 0.2110  data: 0.0034  max mem: 1507
# Epoch: [4]  [290/319]  eta: 0:00:06  lr: 0.000500  loss: 0.1882 (0.2262)  loss_classifier: 0.0226 (0.0397)  loss_box_reg: 0.0272 (0.0523)  loss_mask: 0.1188 (0.1292)  loss_objectness: 0.0009 (0.0029)  loss_rpn_box_reg: 0.0007 (0.0021)  time: 0.2166  data: 0.0034  max mem: 1507
# Epoch: [4]  [300/319]  eta: 0:00:04  lr: 0.000500  loss: 0.1768 (0.2300)  loss_classifier: 0.0226 (0.0412)  loss_box_reg: 0.0272 (0.0537)  loss_mask: 0.1188 (0.1298)  loss_objectness: 0.0008 (0.0031)  loss_rpn_box_reg: 0.0013 (0.0021)  time: 0.2360  data: 0.0035  max mem: 1507
# Epoch: [4]  [310/319]  eta: 0:00:01  lr: 0.000500  loss: 0.1429 (0.2283)  loss_classifier: 0.0137 (0.0407)  loss_box_reg: 0.0221 (0.0532)  loss_mask: 0.1061 (0.1292)  loss_objectness: 0.0005 (0.0031)  loss_rpn_box_reg: 0.0005 (0.0021)  time: 0.2276  data: 0.0035  max mem: 1507
# Epoch: [4]  [318/319]  eta: 0:00:00  lr: 0.000500  loss: 0.1344 (0.2279)  loss_classifier: 0.0137 (0.0406)  loss_box_reg: 0.0265 (0.0533)  loss_mask: 0.0895 (0.1289)  loss_objectness: 0.0005 (0.0030)  loss_rpn_box_reg: 0.0005 (0.0021)  time: 0.2195  data: 0.0035  max mem: 1507
# Epoch: [4] Total time: 0:01:09 (0.2166 s / it)
# creating index...
# index created!
# Test:  [  0/150]  eta: 0:01:19  model_time: 0.0829 (0.0829)  evaluator_time: 0.0243 (0.0243)  time: 0.5290  data: 0.4012  max mem: 1507
# Test:  [100/150]  eta: 0:00:04  model_time: 0.0590 (0.0668)  evaluator_time: 0.0105 (0.0154)  time: 0.0868  data: 0.0042  max mem: 1507
# Test:  [149/150]  eta: 0:00:00  model_time: 0.0576 (0.0686)  evaluator_time: 0.0098 (0.0173)  time: 0.0890  data: 0.0047  max mem: 1507
# Test: Total time: 0:00:14 (0.0964 s / it)
# Averaged stats: model_time: 0.0576 (0.0686)  evaluator_time: 0.0098 (0.0173)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.616
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.805
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.690
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.267
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.389
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.722
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.748
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.787
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.568
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.801
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.654
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.692
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.725

# %%
#to save directory
torch.save(model.state_dict(), 'checkpoints.pth')

# %% [markdown]
# # Inference

# %%
model.load_state_dict(torch.load('checkpoints.pth'))
model.eval()
# Out:
# MaskRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign()
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#     (mask_roi_pool): MultiScaleRoIAlign()
#     (mask_head): MaskRCNNHeads(
#       (mask_fcn1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU(inplace=True)
#       (mask_fcn2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU(inplace=True)
#       (mask_fcn3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu3): ReLU(inplace=True)
#       (mask_fcn4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu4): ReLU(inplace=True)
#     )
#     (mask_predictor): MaskRCNNPredictor(
#       (conv5_mask): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (relu): ReLU(inplace=True)
#       (mask_fcn_logits): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
img, label = dataset_test[100]

with torch.no_grad():
    prediction = model([img.to(device)])

# %%
pred=torch.sum(prediction[0]['masks'],dim=0).squeeze(0)
pred[pred>=0.5]=1
pred[pred<0.5]=0
plt.imshow(pred.mul(255).cpu())
plt.show()

# %%
import matplotlib.pyplot as plt

plt.imshow(img.permute(1, 2, 0))
plt.show()
